# %% [markdown]
# <a href="https://colab.research.google.com/github/krishna5598/Birthday-website/blob/main/vector_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
in_geojson=r'/content/data/municipality.json'
in_shp = r'/content/data/municipality.shp'

# %%
gdf = gpd.read_file(in_geojson)

# %%
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM          Nepali  Shape_Leng  \
# 0  101      1   44.672747    88.825948  10101  आठराई त्रिवेणी    0.430900
# 1  101      2   61.067429   137.848122  10102        मैवाखोला    0.577692
# 2  101      3   75.987469   210.313039  10103        मेरिङदेन    0.718499
# 3  101      4  123.175400   442.960328  10104      मिक्वाखोला    1.164097
# 4  101      5  228.107830  1858.441119  10105       फक्ताङलुङ    2.186142
#
#    Shape_Area                                           geometry
# ...

# %%
gdf.plot(color = 'red', edgecolor = 'black')
# Out:
# <Axes: >

# %%
gdf.plot(cmap = 'jet', edgecolor = 'black', column = 'DISTRICT')
# Out:
# <Axes: >

# %%
gdf.head(20)
# Out:
#     OBJECTID   DISTRICT             GaPa_NaPa      Type_GN Province  SCode  \
# 0          1  TAPLEJUNG       Aathrai Tribeni   Gaunpalika        1      1
# 1          2  TAPLEJUNG            Maiwakhola   Gaunpalika        1      1
# 2          3  TAPLEJUNG             Meringden   Gaunpalika        1      1
# 3          4  TAPLEJUNG            Mikwakhola   Gaunpalika        1      1
# 4          5  TAPLEJUNG          Phaktanglung   Gaunpalika        1      1
# 5          6  TAPLEJUNG             Phungling  Nagarpalika        1      1
# 6          7  TAPLEJUNG              Sidingba   Gaunpalika        1      1
# 7          8  TAPLEJUNG            Sirijangha   Gaunpalika        1      1
# 8          9  TAPLEJUNG  Pathibhara Yangwarak   Gaunpalika        1      1
# 9         10  PANCHTHAR              Falelung   Gaunpalika        1      1
# 10        11  PANCHTHAR            Falgunanda   Gaunpalika        1      1
# ...

# %%
len(gdf)
# Out:
# 774

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf
# Out:
#      OBJECTID       DISTRICT                  GaPa_NaPa          Type_GN  \
# 0           1      TAPLEJUNG            Aathrai Tribeni       Gaunpalika
# 1           2      TAPLEJUNG                 Maiwakhola       Gaunpalika
# 2           3      TAPLEJUNG                  Meringden       Gaunpalika
# 3           4      TAPLEJUNG                 Mikwakhola       Gaunpalika
# 4           5      TAPLEJUNG               Phaktanglung       Gaunpalika
# ..        ...            ...                        ...              ...
# 769       770  NAWALPARASI_E     Chitawan National Park    National Park
# 770       771        RUKUM_E                      Bhume       Gaunpalika
# 771       772        RUKUM_E           Putha Uttarganga       Gaunpalika
# 772       773        RUKUM_E                      Sisne       Gaunpalika
# 773       774        RUKUM_E  Dhorpatan Hunting Reserve  Hunting Reserve
#
#     Province  SCode  DCode  SDD  MCode      length         area  SDDMM  \
# ...

# %%
gdf.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 769    Polygon
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# Length: 774, dtype: object

# %%
gdf.plot('DISTRICT',cmap = 'jet', legend=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
gdf.plot(ax = ax, column = 'Province' , legend = True, legend_kwds={"loc": 'center left'} )
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04,0.5))
